# %% [markdown]
# <a href="https://colab.research.google.com/github/MaikeFogaca/Python-Projects/blob/main/WebScrapingLinkedln.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium

# %%
import pandas as pd
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
pip install webdriver-manager

# %%
browser=webdriver.Chrome("chromedriver.exe")
browser.get("https://www.linkedin.com/")

# %%
username=browser.find_element_by_id("session_key")
username.send_keys("testemaike22@gmail.com")
password=browser.find_element_by_id("session_password")
password.send_keys("suasenha")

# %%
login_button=browser.find_element_by_class_name("sign-in-form__submit-button")
login_button.click()

# %% [markdown]
# Após realização das importações das bibliotecas e do chromedriver irá abrir a tela de login conforme imagem abaixo
#
# ![LoginWebScraping.jpg](data:image/jpeg;base64,...)

# %%
browser.get("https://www.linkedin.com/jobs/")

# %%
job=browser.find_elements_by_classs_name("job-card-square__title")
m=[]
for i in job:
    #print(i.text)
    m.append(i.text)
print(m)
print()
print(len(m))

# %%
job_title=[]
for i in range(len(c)):
    job_title.append(c[i].strip("Job Title\n"))
    job_title
print(0job_title)

# %%
job2=browser.find_elements_by-class_name("job-card-container__company-name")
comp_name=[]
fori in job2:
      #print(i.text)
      comp_name.append(i.text)
print(comp_name)
print()
print(len(comp_name))

# %%
job3 = browser.find_elements_by_class_name("job-card-container__metadata-tem")
loc_name_[]
for i in job3:
    #print(i.text)
    loc_name.append(i.text)
print(loc_name)
print()
print(len(loc_name))

# %%
comp_name.append(" ")
comp_name.append(" ")

# %%
len(comp_name)

# %%
col=["Company Name","job Title","Location"]
df=pd.DataFrame({"Company Name":comp_name[slice(19)],"Job Title":job_title,"Location":loc_name})

# %%
df.head()

# %%
df.to_csv("linkedin_scrapingJobs.csv")
