# %% [markdown]
# <a href="https://colab.research.google.com/github/MaikeFogaca/Python-Projects/blob/main/DadosAluguelimovel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/Datase_imoveis_2.csv',sep=';')

# %%
dataset
# Out:
#                                                endereco      valor  area  \
# 0          Rua Cayowaá, 1258 - Perdizes, São Paulo - SP  1010000.0   110
# 1          Rua Campevas, 238 - Perdizes, São Paulo - SP        0.0   106
# 2          Rua Apinajés, 931 - Perdizes, São Paulo - SP   760000.0    67
# 3     Rua Cardoso de Almeida, 978 - Perdizes, São Pa...   980000.0   117
# 4        Rua dos Caetés, 878 - Perdizes, São Paulo - SP   600000.0    70
# ...                                                 ...        ...   ...
# 3523        Rua Caiubi, 1188 - Perdizes, São Paulo - SP     7300.0   104
# 3524            Rua Caraíbas - Perdizes, São Paulo - SP   990000.0   105
# 3525  Rua Coronel Melo de Oliveira - Perdizes, São P...  1800000.0   143
# 3526       Avenida Antártica - Perdizes, São Paulo - SP   550000.0   106
# 3527                           Perdizes, São Paulo - SP  2250000.0   214
#
#       quartos  vagas  banheiros  pagina
# 0           3      1          3       1
# ...

# %%
tipos_dados = pd.DataFrame(dataset.dtypes,columns=['Tipos de Dados'])
tipos_dados.columns.name='Váriaveis'
tipos_dados
# Out:
# Váriaveis Tipos de Dados
# endereco          object
# valor            float64
# area               int64
# quartos            int64
# vagas              int64
# banheiros          int64
# pagina             int64

# %%
print('Os dados mostram {} registros (imóveis) e {} variáveis'.format(dataset.shape[0],dataset.shape[1]))
# Out:
# Os dados mostram 3528 registros (imóveis) e 7 variáveis

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3528 entries, 0 to 3527
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   endereco   3528 non-null   object
#  1   valor      3528 non-null   float64
#  2   area       3528 non-null   int64
#  3   quartos    3528 non-null   int64
#  4   vagas      3528 non-null   int64
#  5   banheiros  3528 non-null   int64
#  6   pagina     3528 non-null   int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 193.1+ KB

# %%
dados = dataset[(dataset['valor']!=0) & (dataset['area']!=0) ]
dados.shape
# Out:
# (3256, 7)

# %%
dados.dtypes
# Out:
# endereco      object
# valor        float64
# area           int64
# quartos        int64
# vagas          int64
# banheiros      int64
# pagina         int64
# dtype: object

# %%
dados.head()
# Out:
#                                             endereco      valor  area  \
# 0       Rua Cayowaá, 1258 - Perdizes, São Paulo - SP  1010000.0   110
# 2       Rua Apinajés, 931 - Perdizes, São Paulo - SP   760000.0    67
# 3  Rua Cardoso de Almeida, 978 - Perdizes, São Pa...   980000.0   117
# 4     Rua dos Caetés, 878 - Perdizes, São Paulo - SP   600000.0    70
# 5          Rua Diana, 649 - Perdizes, São Paulo - SP   950000.0   105
#
#    quartos  vagas  banheiros  pagina
# 0        3      1          3       1
# 2        2      2          2       1
# 3        3      1          4       1
# 4        2      1          2       1
# 5        3      1          3       1

# %%
dados['valor_m2']=(dados.valor/dados.area).round(0)
dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                             endereco      valor  area  \
# 0       Rua Cayowaá, 1258 - Perdizes, São Paulo - SP  1010000.0   110
# 2       Rua Apinajés, 931 - Perdizes, São Paulo - SP   760000.0    67
# 3  Rua Cardoso de Almeida, 978 - Perdizes, São Pa...   980000.0   117
# 4     Rua dos Caetés, 878 - Perdizes, São Paulo - SP   600000.0    70
# 5          Rua Diana, 649 - Perdizes, São Paulo - SP   950000.0   105
#
#    quartos  vagas  banheiros  pagina  valor_m2
# 0        3      1          3       1    9182.0
# 2        2      2          2       1   11343.0
# ...

# %%
del dados['pagina']

# %% [markdown]
# Estatística Descritiva

# %%
dados[['valor','area','valor_m2']].describe().round(2)
# Out:
#              valor     area  valor_m2
# count      3256.00  3256.00   3256.00
# mean    1563043.83   132.39  11200.54
# std     1181517.20    62.66   3855.56
# min        1700.00    18.00     17.00
# 25%      796500.00    89.00   8929.00
# 50%     1250000.00   119.00  10664.50
# 75%     2000000.00   172.25  13060.00
# max    10314342.00   451.00  38413.00

# %%
# %matplotlib inline
plt.rc('figure',figsize=(20,10))

# %%
dados.hist(['valor_m2'])

# %%
dataset_2 = pd.read_csv('/content/Datase_imoveis_2.csv',sep=';')
dataset_2

# %%
print('Numero de linhas do dataset é {}'.format(dataset_2.shape[0]))
# Out:
# Numero de linhas do dataset é 3528

# %%
dados = dataset_2[(dataset_2['valor']!=0)&(dataset_2['quartos']!=0) & (dataset_2['vagas']!=0)&(dataset_2['banheiros']!=0) ]

# %%
dados.head()
# Out:
#                                             endereco      valor  area  \
# 0       Rua Cayowaá, 1258 - Perdizes, São Paulo - SP  1010000.0   110
# 2       Rua Apinajés, 931 - Perdizes, São Paulo - SP   760000.0    67
# 3  Rua Cardoso de Almeida, 978 - Perdizes, São Pa...   980000.0   117
# 4     Rua dos Caetés, 878 - Perdizes, São Paulo - SP   600000.0    70
# 5          Rua Diana, 649 - Perdizes, São Paulo - SP   950000.0   105
#
#    quartos  vagas  banheiros  pagina
# 0        3      1          3       1
# 2        2      2          2       1
# 3        3      1          4       1
# 4        2      1          2       1
# 5        3      1          3       1
